# %%
# %run ./RIN_Widget.ipynb

min_cutoff = 0.3
max_cutoff = 1.0
frame = 0
numRuns = 1000
numRuns_traj = 1
numRuns_cutoff = 50

myRes_A3D = NetworKitGraphWidget('A3D-0-protein.pdb', trajFile = 'A3D-0-protein-000.dcd')
algoRes_min_A3D = myRes_A3D.benchmarkAlgorithms(numRuns, min_cutoff, frame, only_nwk = True)
algoRes_max_A3D = myRes_A3D.benchmarkAlgorithms(numRuns, max_cutoff, frame)
trajRes_min_A3D = myRes_A3D.benchmarkTrajectory(numRuns_traj, min_cutoff)
trajRes_max_A3D = myRes_A3D.benchmarkTrajectory(numRuns_traj, max_cutoff)
cutoff_A3D = myRes_A3D.benchmarkEdgeLayoutGeneration(numRuns_cutoff)
algoRes_complete_A3D = myRes_A3D.benchmarkAlgorithms(numRuns, max_cutoff, frame, only_nwk = False)
trajRes_complete_A3D = myRes_A3D.benchmarkCompleteTrajectory(numRuns_traj, max_cutoff)
cutoffRes_complete_A3D = myRes_A3D.benchmarkCompleteCutOff(numRuns_cutoff)
print("Finished A3D")

myRes_2JOF = NetworKitGraphWidget('2JOF-0-protein.pdb', trajFile = '2JOF-0-protein-000.dcd')
algoRes_min_2JOF = myRes_2JOF.benchmarkAlgorithms(numRuns, min_cutoff, frame)
algoRes_max_2JOF = myRes_2JOF.benchmarkAlgorithms(numRuns, max_cutoff, frame)
trajRes_min_2JOF = myRes_2JOF.benchmarkTrajectory(numRuns_traj, min_cutoff)
trajRes_max_2JOF = myRes_2JOF.benchmarkTrajectory(numRuns_traj, max_cutoff)
cutoff_2JOF = myRes_2JOF.benchmarkEdgeLayoutGeneration(numRuns_cutoff)
algoRes_complete_2JOF = myRes_2JOF.benchmarkAlgorithms(numRuns, max_cutoff, frame, only_nwk = False)
trajRes_complete_2JOF = myRes_2JOF.benchmarkCompleteTrajectory(numRuns_traj, max_cutoff)
cutoffRes_complete_2JOF = myRes_2JOF.benchmarkCompleteCutOff(numRuns_cutoff)
print("Finished 2JOF")

myRes_NTL9 = NetworKitGraphWidget('NTL9-0-protein.pdb', trajFile = 'NTL9-0-protein-000.dcd')
algoRes_min_NTL9 = myRes_NTL9.benchmarkAlgorithms(numRuns, min_cutoff, frame)
algoRes_max_NTL9 = myRes_NTL9.benchmarkAlgorithms(numRuns, max_cutoff, frame)
trajRes_min_NTL9 = myRes_NTL9.benchmarkTrajectory(numRuns_traj, min_cutoff)
trajRes_max_NTL9 = myRes_NTL9.benchmarkTrajectory(numRuns_traj, max_cutoff)
cutoff_NTL9 = myRes_NTL9.benchmarkEdgeLayoutGeneration(numRuns_cutoff)
algoRes_complete_NTL9 = myRes_NTL9.benchmarkAlgorithms(numRuns, max_cutoff, frame, only_nwk = False)
trajRes_complete_NTL9 = myRes_NTL9.benchmarkCompleteTrajectory(numRuns_traj, max_cutoff)
cutoffRes_complete_NTL9 = myRes_NTL9.benchmarkCompleteCutOff(numRuns_cutoff)
print("Finished NTL9")
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# ...

# %%
data_min_algo_plt = []

i = 0
for key, value in algoRes_min_A3D[1].items():
    data_min_algo_plt.append([])
    data_min_algo_plt[i] += [np.mean(algoRes_min_A3D[1][key])]
    data_min_algo_plt[i] += [np.mean(algoRes_min_2JOF[1][key])]
    data_min_algo_plt[i] += [np.mean(algoRes_min_NTL9[1][key])]
    i = i + 1
    
data_max_algo_plt = []

i = 0
for key, value in algoRes_max_A3D[1].items():
    data_max_algo_plt.append([])
    data_max_algo_plt[i] += [np.mean(algoRes_max_A3D[1][key])]
    data_max_algo_plt[i] += [np.mean(algoRes_max_2JOF[1][key])]
    data_max_algo_plt[i] += [np.mean(algoRes_max_NTL9[1][key])]
    i = i + 1

data_min_traj_plt = [0.0, 0.0, 0.0]
data_min_traj_plt[0] = trajRes_min_A3D[1][0] * 2
data_min_traj_plt[1] = trajRes_min_2JOF[1][0] * 2
data_min_traj_plt[2] = trajRes_min_NTL9[1][0] * 2

data_max_traj_plt = [0.0, 0.0, 0.0]
data_max_traj_plt[0] = trajRes_max_A3D[1][0] * 2
data_max_traj_plt[1] = trajRes_max_2JOF[1][0] * 2
data_max_traj_plt[2] = trajRes_max_NTL9[1][0] * 2

data_edge_plt = []

i = 0
for key, value in cutoff_A3D[0].items():
    data_edge_plt.append([])
    data_edge_plt[i] += [np.mean(cutoff_A3D[0][key])]
    data_edge_plt[i] += [np.mean(cutoff_2JOF[0][key])]
    data_edge_plt[i] += [np.mean(cutoff_NTL9[0][key])]
    i = i + 1

data_layout_plt = []

i = 0
for key, value in cutoff_A3D[1].items():
    data_layout_plt.append([])
    data_layout_plt[i] += [np.mean(cutoff_A3D[1][key])]
    data_layout_plt[i] += [np.mean(cutoff_2JOF[1][key])]
    data_layout_plt[i] += [np.mean(cutoff_NTL9[1][key])]
    i = i + 1
    
data_complete_algo_plt = []

i = 0
for key, value in algoRes_complete_A3D[1].items():
    data_complete_algo_plt.append([])
    data_complete_algo_plt[i] += [np.mean(algoRes_complete_A3D[1][key])]
    data_complete_algo_plt[i] += [np.mean(algoRes_complete_2JOF[1][key])]
    data_complete_algo_plt[i] += [np.mean(algoRes_complete_NTL9[1][key])]
    i = i + 1
    
data_complete_traj_plt = [0.0, 0.0, 0.0]
data_complete_traj_plt[0] = np.mean(trajRes_complete_A3D) * 2
data_complete_traj_plt[1] = np.mean(trajRes_complete_2JOF) * 2
data_complete_traj_plt[2] = np.mean(trajRes_complete_NTL9) * 2

data_complete_cutoff_plt = []

i = 0
for key, value in cutoffRes_complete_A3D.items():
    data_complete_cutoff_plt.append([])
    data_complete_cutoff_plt[i] += [np.mean(cutoffRes_complete_A3D[key])]
    data_complete_cutoff_plt[i] += [np.mean(cutoffRes_complete_2JOF[key])]
    data_complete_cutoff_plt[i] += [np.mean(cutoffRes_complete_NTL9[key])]
    i = i + 1

# plot
barWidth = 0.10
br0 = np.arange(len(data_min_algo_plt[0]))
br1 = [x + barWidth for x in br0]
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]
br6 = [x + barWidth for x in br5]
br7 = [x + barWidth for x in br6]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.transforms as mtransforms
import seaborn as sns

plt.style.use('seaborn-colorblind')

fig = plt.figure(figsize =(45, 10), constrained_layout = True)
axs = fig.subplots(1, 3)

trans = mtransforms.ScaledTranslation(5/72, 35/72, fig.dpi_scale_trans)

curFig = axs[0]
curFig.bar(br0, data_min_algo_plt[0], width = barWidth,
        label ='Betweenness Centrality')
curFig.bar(br1, data_min_algo_plt[1], width = barWidth,
        edgecolor ='grey', label ='Closeness Centrality')
curFig.bar(br2, data_min_algo_plt[2], width = barWidth,
        edgecolor ='grey', label ='Degree Centrality')
curFig.bar(br3, data_min_algo_plt[3], width = barWidth,
        edgecolor ='grey', label ='Eigenvector Centrality')
curFig.bar(br4, data_min_algo_plt[4], width = barWidth,
        edgecolor ='grey', label ='Katz Centrality')
curFig.bar(br5, data_min_algo_plt[5], width = barWidth,
        edgecolor ='grey', label ='PLM Community Detection')
curFig.bar(br6, data_min_algo_plt[6], width = barWidth,
        edgecolor ='grey', label ='PLP Community Detection')

curFig = axs[1]
curFig.bar(br0, data_max_algo_plt[0], width = barWidth,
        edgecolor ='grey', label ='Betweenness Centrality')
curFig.bar(br1, data_max_algo_plt[1], width = barWidth,
        edgecolor ='grey', label ='Closeness Centrality')
curFig.bar(br2, data_max_algo_plt[2], width = barWidth,
        edgecolor ='grey', label ='Degree Centrality')
curFig.bar(br3, data_max_algo_plt[3], width = barWidth,
        edgecolor ='grey', label ='Eigenvector Centrality')
curFig.bar(br4, data_max_algo_plt[4], width = barWidth,
        edgecolor ='grey', label ='Katz Centrality')
curFig.bar(br5, data_max_algo_plt[5], width = barWidth,
        edgecolor ='grey', label ='PLM Community Detection')
curFig.bar(br6, data_max_algo_plt[6], width = barWidth,
        edgecolor ='grey', label ='PLP Community Detection')

curFig = axs[2]
curFig.bar(br0, data_complete_algo_plt[0], width = barWidth,
        edgecolor ='grey', label ='Betweenness Centrality')
curFig.bar(br1, data_complete_algo_plt[1], width = barWidth,
        edgecolor ='grey', label ='Closeness Centrality')
curFig.bar(br2, data_complete_algo_plt[2], width = barWidth,
        edgecolor ='grey', label ='Degree Centrality')
curFig.bar(br3, data_complete_algo_plt[3], width = barWidth,
        edgecolor ='grey', label ='Eigenvector Centrality')
curFig.bar(br4, data_complete_algo_plt[4], width = barWidth,
        edgecolor ='grey', label ='Katz Centrality')
curFig.bar(br5, data_complete_algo_plt[5], width = barWidth,
        edgecolor ='grey', label ='PLM Community Detection')
curFig.bar(br6, data_complete_algo_plt[6], width = barWidth,
        edgecolor ='grey', label ='PLP Community Detection')

fsize = 30
lsize = 28
fweight = 'normal'

curFig = axs[0]
curFig.set_xlabel('RIN Graph Measure Switch\nNetworKit update time (cut-off: 3.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_min_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0 (edges='+str(algoRes_min_A3D[0]['e'])+')', '2JOF-0 (edges=' +str(algoRes_min_2JOF[0]['e'])+')', 'NTL9-0 (edges='+str(algoRes_min_NTL9[0]['e'])+')'])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(a)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))
curFig.legend(fontsize=fsize)

curFig = axs[1]
curFig.set_xlabel('RIN Graph Measure Switch\nNetworKit update time (cut-off: 10.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_max_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0 (edges='+str(algoRes_max_A3D[0]['e'])+')', '2JOF-0 (edges=' +str(algoRes_max_2JOF[0]['e'])+')', 'NTL9-0 (edges='+str(algoRes_max_NTL9[0]['e'])+')'])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(b)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

curFig = axs[2]
curFig.set_xlabel('RIN Graph Measure Switch\nTotal update time (cut-off: 10.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_complete_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0', '2JOF-0', 'NTL9-0'])
curFig.set_ylim([0,70])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(c)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

plt.show()
fig.savefig("plotlybridge-data-algo.pdf")

# %%
blindCmap = sns.color_palette('colorblind', 11)

myCmap = sns.light_palette(blindCmap[1], 8)

fig = plt.figure(figsize =(45, 10), constrained_layout = True)
axs = fig.subplots(1, 3)

curFig = axs[0]
curFig.bar(br0, data_edge_plt[0], width = barWidth,
        edgecolor ='grey', label ='3.0 Å', color=myCmap[0])
curFig.bar(br1, data_edge_plt[1], width = barWidth,
        edgecolor ='grey', label ='4.0 Å', color=myCmap[1])
curFig.bar(br2, data_edge_plt[2], width = barWidth,
        edgecolor ='grey', label ='5.0 Å', color=myCmap[2])
curFig.bar(br3, data_edge_plt[3], width = barWidth,
        edgecolor ='grey', label ='6.0 Å', color=myCmap[3])
curFig.bar(br4, data_edge_plt[4], width = barWidth,
        edgecolor ='grey', label ='7.0 Å', color=myCmap[4])
curFig.bar(br5, data_edge_plt[5], width = barWidth,
        edgecolor ='grey', label ='8.0 Å', color=myCmap[5])
curFig.bar(br6, data_edge_plt[6], width = barWidth,
        edgecolor ='grey', label ='9.0 Å', color=myCmap[6])
curFig.bar(br7, data_edge_plt[7], width = barWidth,
        edgecolor ='grey', label ='10.0 Å', color=myCmap[7])

curFig = axs[1]
curFig.bar(br0, data_layout_plt[0], width = barWidth,
        edgecolor ='grey', label ='3.0 Å', color=myCmap[0])
curFig.bar(br1, data_layout_plt[1], width = barWidth,
        edgecolor ='grey', label ='4.0 Å', color=myCmap[1])
curFig.bar(br2, data_layout_plt[2], width = barWidth,
        edgecolor ='grey', label ='5.0 Å', color=myCmap[2])
curFig.bar(br3, data_layout_plt[3], width = barWidth,
        edgecolor ='grey', label ='6.0 Å', color=myCmap[3])
curFig.bar(br4, data_layout_plt[4], width = barWidth,
        edgecolor ='grey', label ='7.0 Å', color=myCmap[4])
curFig.bar(br5, data_layout_plt[5], width = barWidth,
        edgecolor ='grey', label ='8.0 Å', color=myCmap[5])
curFig.bar(br6, data_layout_plt[6], width = barWidth,
        edgecolor ='grey', label ='9.0 Å', color=myCmap[6])
curFig.bar(br7, data_layout_plt[7], width = barWidth,
        edgecolor ='grey', label ='10.0 Å', color=myCmap[7])

curFig = axs[2]
curFig.bar(br0, data_complete_cutoff_plt[0], width = barWidth,
        edgecolor ='grey', label ='3.0 Å', color=myCmap[0])
curFig.bar(br1, data_complete_cutoff_plt[1], width = barWidth,
        edgecolor ='grey', label ='4.0 Å', color=myCmap[1])
curFig.bar(br2, data_complete_cutoff_plt[2], width = barWidth,
        edgecolor ='grey', label ='5.0 Å', color=myCmap[2])
curFig.bar(br3, data_complete_cutoff_plt[3], width = barWidth,
        edgecolor ='grey', label ='6.0 Å', color=myCmap[3])
curFig.bar(br4, data_complete_cutoff_plt[4], width = barWidth,
        edgecolor ='grey', label ='7.0 Å', color=myCmap[4])
curFig.bar(br5, data_complete_cutoff_plt[5], width = barWidth,
        edgecolor ='grey', label ='8.0 Å', color=myCmap[5])
curFig.bar(br6, data_complete_cutoff_plt[6], width = barWidth,
        edgecolor ='grey', label ='9.0 Å', color=myCmap[6])
curFig.bar(br7, data_complete_cutoff_plt[7], width = barWidth,
        edgecolor ='grey', label ='10.0 Å', color=myCmap[7])

fsize = 30
lsize = 28
fweight = 'normal'

curFig = axs[0]
curFig.set_xlabel('RIN Cut-off Distance Switch\nNetworKit update time (edge update)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_min_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0', '2JOF-0', 'NTL9-0'])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(d)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))
curFig.legend(fontsize=fsize, ncol=2)

curFig = axs[1]
curFig.set_xlabel('RIN Cut-off Distance Switch\nNetworKit update time (layout generation)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_max_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0', '2JOF-0', 'NTL9-0'])
curFig.set_ylim([0,550])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(e)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

curFig = axs[2]
curFig.set_xlabel('RIN Cut-off Distance Switch\nTotal update time (edge update + layout generation)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + 3 * barWidth for r in range(len(data_complete_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0', '2JOF-0', 'NTL9-0'])
curFig.set_ylim([0,550])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(f)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

plt.show()
fig.savefig("plotlybridge-data-cutoff.pdf")

# %%
fig = plt.figure(figsize =(45, 10), constrained_layout = True)
axs = fig.subplots(1, 3)

curFig = axs[0]
curFig.bar(br0, data_min_traj_plt, width = 5* barWidth, color = blindCmap[2],
        edgecolor ='grey', label ='Edge + Layout Generation')

curFig = axs[1]
curFig.bar(br0, data_max_traj_plt, width = 5* barWidth, color = blindCmap[2],
        edgecolor ='grey', label ='Edge + Layout Generation')

curFig = axs[2]
curFig.bar(br0, data_complete_traj_plt, width = 5* barWidth, color = blindCmap[2],
        edgecolor ='grey', label ='Edge + Layout Generation')

fsize = 30
lsize = 28
fweight = 'normal'

curFig = axs[0]
curFig.set_xlabel('RIN Trajectory Frame Switch\nNetworKit update time (cut-off: 3.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + barWidth / 4.0 for r in range(len(data_min_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0\n(avg. edges='+str(round(trajRes_min_A3D[0]['e']))+')', '2JOF-0\n(avg. edges=' +str(round(trajRes_min_2JOF[0]['e']))+')', 'NTL9-0\n(avg. edges='+str(round(trajRes_min_NTL9[0]['e']))+')'])
curFig.set_ylim([0,600])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(g)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

curFig = axs[1]
curFig.set_xlabel('RIN Trajectory Frame Switch\nNetworKit update time (cut-off: 10.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + barWidth / 4.0 for r in range(len(data_max_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0\n(avg. edges='+str(round(trajRes_max_A3D[0]['e']))+')', '2JOF-0\n(avg. edges=' +str(round(trajRes_max_2JOF[0]['e']))+')', 'NTL9-0\n(avg. edges='+str(round(trajRes_max_NTL9[0]['e']))+')'])
curFig.set_ylim([0,600])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(h)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

curFig = axs[2]
curFig.set_xlabel('RIN Trajectory Frame Switch\nTotal update time (cut-off: 10.0 Å)', fontweight =fweight, fontsize = fsize)
curFig.xaxis.labelpad = 15
curFig.yaxis.labelpad = 15
curFig.set_ylabel('Execution time in ms', fontweight =fweight, fontsize = fsize)
curFig.set_xticks([r + barWidth / 4.0 for r in range(len(data_complete_algo_plt[0]))])
curFig.set_xticklabels(['A3D-0\n(avg. edges='+str(round(trajRes_max_A3D[0]['e']))+')', '2JOF-0\n(avg. edges=' +str(round(trajRes_max_2JOF[0]['e']))+')', 'NTL9-0\n(avg. edges='+str(round(trajRes_max_NTL9[0]['e']))+')'])
curFig.set_ylim([0,600])
curFig.tick_params(axis='both', labelsize=lsize)
curFig.text(0.0, 1.0, '(i)', transform=curFig.transAxes + trans,
            fontsize=fsize, verticalalignment='top',
            bbox=dict(facecolor='1.0', edgecolor='none', pad=3.0))

plt.show()
fig.savefig("plotlybridge-data-trajectory.pdf")
